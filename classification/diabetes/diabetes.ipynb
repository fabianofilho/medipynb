# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd #análise de dados em tabelas
import numpy as np #análise de números
import seaborn as sb #análise em gráficos

# %% [markdown]
# # Diabetes Machine Learning Classification Model
# With numerical variables
# and Cross Validation.

# %% [markdown]
# Cols: 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'

# %%
import pandas as pd

# %%
names = ['preg', 'glic', 'pres', 'skin', 'ins', 'bmi', 'dpf', 'age', 'target']

# %%
d = pd.read_csv('http://bit.ly/pimadiabetes', names=names)
d.head()
# Out:
#    preg  glic  pres  skin  ins   bmi     dpf  age  target
# 0     6   148    72    35    0  33.6   627.0   50       1
# 1     1    85    66    29    0  26.6   351.0   31       0
# 2     8   183    64     0    0  23.3   672.0   32       1
# 3     1    89    66    23   94  28.1   167.0   21       0
# 4     0   137    40    35  168  43.1  2288.0   33       1

# %%
d.head(2)
# Out:
#    preg  glic  pres  skin  ins   bmi    dpf  age  target
# 0     6   148    72    35    0  33.6  627.0   50       1
# 1     1    85    66    29    0  26.6  351.0   31       0

# %%
X = d.drop('target', axis=1)
y = d['target']

# %%
from sklearn.model_selection import train_test_split
# implementing train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# Import models
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
clf1 = LogisticRegression() # regressão logistica
clf2 = RandomForestClassifier() # arvores aleatorias
clf3 = xgb.XGBClassifier() # boost gradient
clf4 = SVC(gamma='auto')
clf5 = KNeighborsClassifier(n_neighbors=3)

# Train, Predict and Evaluate the model 
from sklearn.metrics import accuracy_score, classification_report, recall_score, confusion_matrix
from sklearn.model_selection import cross_val_score
for clf, label in zip([clf1, clf2, clf3, clf4, clf5], 
                      ['Logistic Regression', 'Random Forest', 'XGBoost', 'SVM', 'KNN']):
    clf.fit(X_train, y_train) #training model
    p = clf.predict(X_test) #predicting model
    cv_score = cross_val_score(clf, X, y, cv=10, scoring='roc_auc')
    score = clf.score(X_test, y_test)
    print(label)
    print(classification_report(y_test, p)) #evaluating model
    print('\n')
    print('Sensibilidade =', recall_score(y_test, p))
    print('\n')
    print("=== Confusion Matrix ===")
    print(confusion_matrix(y_test, p))
    print('\n')
    print("=== Classification Report ===")
    print(classification_report(y_test, p))
    print('\n')
    print("=== All AUC Scores ===")
    print(cv_score)
    print('\n')
    print("=== Mean AUC Score ===")
    print("Mean AUC Score: ", label, cv_score.mean())
    print("_______________________________________________________")
# Out:
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       151
#            1       0.69      0.61      0.65        80
#
#     accuracy                           0.77       231
#    macro avg       0.75      0.73      0.74       231
# weighted avg       0.77      0.77      0.77       231
#
#
#
# Sensibilidade = 0.6125
#
#
# === Confusion Matrix ===
# [[129  22]
#  [ 31  49]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       151
#            1       0.69      0.61      0.65        80
#
#     accuracy                           0.77       231
#    macro avg       0.75      0.73      0.74       231
# weighted avg       0.77      0.77      0.77       231
#
#
#
# === All AUC Scores ===
# [0.77555556 0.80296296 0.82814815 0.78814815 0.80296296 0.84444444
#  0.80888889 0.91851852 0.87076923 0.82846154]
#
#
# === Mean AUC Score ===
# Mean AUC Score:  Logistic Regression 0.8268860398860399
# _______________________________________________________
# Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       151
#            1       0.73      0.72      0.73        80
#
#     accuracy                           0.81       231
#    macro avg       0.79      0.79      0.79       231
# weighted avg       0.81      0.81      0.81       231
#
#
#
# Sensibilidade = 0.725
#
#
# === Confusion Matrix ===
# [[130  21]
#  [ 22  58]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       151
#            1       0.73      0.72      0.73        80
#
#     accuracy                           0.81       231
#    macro avg       0.79      0.79      0.79       231
# weighted avg       0.81      0.81      0.81       231
#
#
#
# === All AUC Scores ===
# [0.76851852 0.79888889 0.81185185 0.68       0.72       0.79148148
#  0.83851852 0.80925926 0.76923077 0.82461538]
#
#
# === Mean AUC Score ===
# Mean AUC Score:  Random Forest 0.7812364672364672
# _______________________________________________________
# XGBoost
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       151
#            1       0.61      0.66      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.72      0.71       231
# weighted avg       0.74      0.74      0.74       231
#
#
#
# Sensibilidade = 0.6625
#
#
# === Confusion Matrix ===
# [[117  34]
#  [ 27  53]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       151
#            1       0.61      0.66      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.72      0.71       231
# weighted avg       0.74      0.74      0.74       231
#
#
#
# === All AUC Scores ===
# [0.80666667 0.84666667 0.81185185 0.70888889 0.82444444 0.85185185
#  0.86       0.92222222 0.82384615 0.83384615]
#
#
# === Mean AUC Score ===
# Mean AUC Score:  XGBoost 0.8290284900284901
# _______________________________________________________
# SVM
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79       151
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.65       231
#    macro avg       0.33      0.50      0.40       231
# weighted avg       0.43      0.65      0.52       231
#
#
#
# Sensibilidade = 0.0
#
#
# === Confusion Matrix ===
# [[151   0]
#  [ 80   0]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79       151
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.65       231
#    macro avg       0.33      0.50      0.40       231
# weighted avg       0.43      0.65      0.52       231
#
#
#
# === All AUC Scores ===
# [0.46222222 0.54962963 0.54       0.48222222 0.49296296 0.49074074
#  0.5562963  0.44962963 0.53423077 0.52076923]
#
#
# === Mean AUC Score ===
# Mean AUC Score:  SVM 0.5078703703703703
# _______________________________________________________
# KNN
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       151
#            1       0.51      0.45      0.48        80
#
#     accuracy                           0.66       231
#    macro avg       0.62      0.61      0.61       231
# weighted avg       0.65      0.66      0.66       231
#
#
#
# Sensibilidade = 0.45
#
#
# === Confusion Matrix ===
# [[117  34]
#  [ 44  36]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       151
#            1       0.51      0.45      0.48        80
#
#     accuracy                           0.66       231
#    macro avg       0.62      0.61      0.61       231
# weighted avg       0.65      0.66      0.66       231
#
#
#
# === All AUC Scores ===
# [0.62037037 0.79074074 0.69592593 0.6562963  0.67037037 0.6462963
#  0.62962963 0.69555556 0.65692308 0.65269231]
#
#
# === Mean AUC Score ===
# Mean AUC Score:  KNN 0.671480056980057
# _______________________________________________________
# C:\Users\fabia\Miniconda3\envs\ds\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
scores
# Out:
# array([0.66233766, 0.66233766], dtype=float32)
